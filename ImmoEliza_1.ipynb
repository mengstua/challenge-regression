# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('ml_ready_real_estate_data.csv')
df.head()
# Out:
#    bedroomCount  bathroomCount  habitableSurface  toiletCount  postCode  \
# 0           2.0            1.0             100.0          1.0      1040
# 1           4.0            2.0             270.0          3.0      1040
# 2           2.0            1.0              87.0          1.0      1040
# 3           2.0            2.0             104.0          2.0      1040
# 4           1.0            1.0              71.0          1.0      1040
#
#    totalParkingCount  province_encoded  type_encoded  subtype_encoded  \
# 0                1.0                 1             1                1
# 1                0.0                 1             2                2
# 2                0.0                 1             1                1
# 3                0.0                 1             1                1
# 4                0.0                 1             1                3
#
#    locality_encoded  ...  hasSwimmingPool_encoded  hasFireplace_encoded  \
# ...

# %% [markdown]
# Step1: Importing Libraries

# %%
df.columns.tolist()
# Out:
# ['bedroomCount',
#  'bathroomCount',
#  'habitableSurface',
#  'toiletCount',
#  'postCode',
#  'totalParkingCount',
#  'province_encoded',
#  'type_encoded',
#  'subtype_encoded',
#  'locality_encoded',
#  'epcScore_encoded',
#  'hasAttic_encoded',
#  'hasGarden_encoded',
#  'hasAirConditioning_encoded',
#  'hasArmoredDoor_encoded',
#  'hasVisiophone_encoded',
#  'hasTerrace_encoded',
#  'hasOffice_encoded',
#  'hasSwimmingPool_encoded',
#  'hasFireplace_encoded',
#  'hasBasement_encoded',
#  'hasDressingRoom_encoded',
#  'hasDiningRoom_encoded',
#  'hasLift_encoded',
#  'hasHeatPump_encoded',
#  'hasPhotovoltaicPanels_encoded',
#  'hasLivingRoom_encoded',
#  'price']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Step2: Loading Dataset

# %% [markdown]
# Step3: Selecting Features for Visualization

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('ml_ready_real_estate_data.csv')
x  = df.iloc[:, :-1]
y = df.iloc[:, -1]

# Split data into training and testing sets (80% train, 20% test)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.5, random_state=42, shuffle =True)

# Initialize and train the model
model = LinearRegression()
model.fit(x_train, y_train)

# Make predictions on test data
y_pred = model.predict(x_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse:.2f}")
print(f"R^2 Score: {r2:.2f}")
# Out:
# Mean Squared Error: 108904993539.57
# R^2 Score: 0.36

# %%
plt.figure(figsize=(8, 8))
plt.scatter(y_test, y_pred, alpha=0.5, color='blue', label='Predicted vs Actual')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='red', linewidth=2, label='Ideal Fit Line')
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.title('Actual vs Predicted House Prices')
plt.legend()
plt.grid(True)
plt.show()

# %%
corr_matrix = df.corr()

# Plot heatmap of correlations
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap='coolwarm', square=False, cbar_kws={"shrink": .8})
plt.title("Correlation Matrix Heatmap")
plt.show()

# %%
# Get correlation of all variables with the target (last column assumed to be 'Price')
target_col = df.columns[-1]
correlations = corr_matrix[target_col].drop(target_col)  # drop correlation with itself

# Get top 5 variables with highest absolute correlation to the target
top_10 = correlations.abs().sort_values(ascending=False).head(10)

print("Top 5 variables most correlated with Price:")
print(top_10)
# Out:
# Top 5 variables most correlated with Price:
# bathroomCount              0.501759
# toiletCount                0.355912
# bedroomCount               0.351888
# hasSwimmingPool_encoded    0.248684
# subtype_encoded            0.226019
# totalParkingCount          0.205422
# hasOffice_encoded          0.188418
# province_encoded           0.158014
# epcScore_encoded           0.149425
# hasFireplace_encoded       0.126290
# Name: price, dtype: float64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('dataset_wout_price_outliers.csv')
df.columns.tolist()
# Out:
# ['bedroomCount',
#  'bathroomCount',
#  'habitableSurface',
#  'toiletCount',
#  'postCode',
#  'totalParkingCount',
#  'province_encoded',
#  'type_encoded',
#  'subtype_encoded',
#  'locality_encoded',
#  'epcScore_encoded',
#  'hasAttic_encoded',
#  'hasGarden_encoded',
#  'hasAirConditioning_encoded',
#  'hasArmoredDoor_encoded',
#  'hasVisiophone_encoded',
#  'hasTerrace_encoded',
#  'hasOffice_encoded',
#  'hasSwimmingPool_encoded',
#  'hasFireplace_encoded',
#  'hasBasement_encoded',
#  'hasDressingRoom_encoded',
#  'hasDiningRoom_encoded',
#  'hasLift_encoded',
#  'hasHeatPump_encoded',
#  'hasPhotovoltaicPanels_encoded',
#  'hasLivingRoom_encoded',
#  'price']

# %%
df.to_csv('updated_pricePereSurface_file.csv')

# %%
df.columns.to_flat_index()
print(len(df.columns))
# Out:
# 27

# %%
df['habitableSurface'].dtypes
# Out:
# dtype('float64')

# %%
price_per_surface = 
df['price_per_surface'] =price_per_surface
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 price_per_surface = df['price']/pd['habitableSurface']
#       2 df['price_per_surface'] =price_per_surface
#
# TypeError: 'module' object is not subscriptable

# %%
x  = df.iloc[:, :-1]
y = df.iloc[:, -1]

# Split data into training and testing sets (80% train, 20% test)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Initialize and train the model
model = LinearRegression()
model.fit(x_train, y_train)

# Make predictions on test data
y_pred = model.predict(x_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse:.2f}")
print(f"R^2 Score: {r2:.2f}")
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))

# %%
plt.figure(figsize=(8, 8))
plt.scatter(y_test, y_pred, alpha=0.5, color='blue', label='Predicted vs Actual')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='red', linewidth=2, label='Ideal Fit Line')
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.title('Actual vs Predicted House Prices')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Step5: Initializing and Training Model

# %% [markdown]
# Step6: Making Predictions

# %%
# Get correlation of all variables with the target (last column assumed to be 'Price')
target_col = df.columns[-1]
correlations = corr_matrix[target_col].drop(target_col)  # drop correlation with itself

# Get top 5 variables with highest absolute correlation to the target
top_10 = correlations.abs().sort_values(ascending=False).head(10)

print("Top 5 variables most correlated with Price:")
print(top_10)
# Out:
# Top 5 variables most correlated with Price:
# bathroomCount              0.501759
# toiletCount                0.355912
# bedroomCount               0.351888
# hasSwimmingPool_encoded    0.248684
# subtype_encoded            0.226019
# totalParkingCount          0.205422
# hasOffice_encoded          0.188418
# province_encoded           0.158014
# epcScore_encoded           0.149425
# hasFireplace_encoded       0.126290
# Name: price, dtype: float64

# %% [markdown]
# Step7: Visualizing Best Fit Line in 3D

# %%
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor
 # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
from sklearn import tree

df = pd.read_csv('dataset_wout_price_outliers.csv')
x  = df.iloc[:, :-1]
y = df.iloc[:, -1]

# Split data into training and testing sets (80% train, 20% test)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# Initialize and train the model
model = DecisionTreeClassifier()
model= model.fit(x_train, y_train)

# Make predictions on test data
y_pred = model.predict(x_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse:.2f}")
print(f"R^2 Score: {r2:.2f}")

# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Mean Squared Error: 18093862918.04
# R^2 Score: 0.33
# Accuracy: 0.07819770202259994

# %%
plt.plot_tree(model)

# %%
plt.figure(figsize=(8, 8))
plt.scatter(y_test, y_pred, alpha=0.5, color='blue', label='Predicted vs Actual')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='red', linewidth=3, label='Ideal Fit Line')
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.title('Actual vs Predicted House Prices')
plt.legend()
plt.grid(True)
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np

df_prepro = df.copy()
columns = ['habitableSurface',  'price']
for col in columns:
    df_prepro[col] = MinMaxScaler().fit_transform(np.array(df_prepro[col]).reshape(-1, 1))
display(df_prepro)
# Out:
#        bedroomCount  bathroomCount  habitableSurface  toiletCount  postCode  \
# 0               2.0            1.0          0.000507          1.0      1040
# 1               4.0            2.0          0.001424          3.0      1040
# 2               2.0            1.0          0.000437          1.0      1040
# 3               2.0            2.0          0.000529          2.0      1040
# 4               1.0            1.0          0.000351          1.0      1040
# ...             ...            ...               ...          ...       ...
# 76098           4.0            2.0          0.001273          2.0      9990
# 76099           3.0            1.0          0.000475          1.0      1090
# 76100           3.0            1.0          0.000577          1.0      1853
# 76101           3.0            2.0          0.000567          2.0      8434
# 76102           3.0            2.0          0.000680          2.0      2610
#
# ...

# %%
df.to_csv('update_scaled.csv')

# %%
from sklearn.tree import export_graphviz
from IPython.display import Image
import pydotplus
from io import StringIO

# X: first 27 columns → features
df_RF = pd.read_csv('update_scaled')
X = df.iloc[:, :27]

# y: last column → target
y = df.iloc[:, 27]

# Train the model (if not already done)
# from sklearn.tree import DecisionTreeClassifier
# model = DecisionTreeClassifier()
# model.fit(X, y)

# Create DOT data
dot_data = StringIO()
export_graphviz(
    model,
    out_file=dot_data,
    filled=True,
    rounded=True,
    special_characters=True,
    feature_names=X.columns  # <-- use correct feature names
)

# Generate the graph
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())

# Save and display the tree
graph.write_png('diabetes.png')
Image(filename='diabetes.png')

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

# importing the file 
df = pd.read_csv('dataset_wout_price_outliers.csv')
X  = df.iloc[:, :-1]
y = df.iloc[:, -1]

# preparing data for trqining and testing

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state = 42, shuffle = True)

# Formulating the Model

model_RF = RandomForestRegressor()
model_RF = model_RF.fit(X_train, y_train)

# Predicting the model

Y_pred_RF = model_RF.predict(X_test)

# accuracy of the model

MSE = mean_squared_error(y_test, Y_pred_RF)
r2 = r2_score(y_test, Y_pred_RF)

print(f'Mean Square Error: {MSE}')
print(f'r2-Score: {r2}')
# Out:
# Mean Square Error: 8235798967.912446
# r2-Score: 0.692864157624721

# %%
from sklearn import metrics
import matplotlib as plt
confusion_matrix = metrics.confusion_matrix(y_test, Y_pred_RF)

cm_display = metrics.ConsfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [0, 1])
cm_display.plot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 from sklearn import metrics
#       2 import matplotlib as plt
# ----> 3 confusion_matrix = metrics.confusion_matrix(y_test, Y_pred_RF)
#       5 cm_display = metrics.ConsfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [0, 1])
#       6 cm_display.plot()
#
# NameError: name 'y_test' is not defined

# %%
plt.figure(figsize=(8, 8))
plt.scatter(y_test, y_pred, alpha=0.5, color='blue', label='Predicted vs Actual')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='red', linewidth=3, label='Ideal Fit Line')
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.title('Actual vs Predicted House Prices')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Get correlation of all variables with the target (last column assumed to be 'Price')
target_col = df.columns[-1]
correlations = corr_matrix[target_col].drop(target_col)  # drop correlation with itself

# Get top 5 variables with highest absolute correlation to the target
top_10 = correlations.abs().sort_values(ascending=False).head(10)

print("Top 5 variables most correlated with Price:")
print(top_10)
# Out:
# Top 5 variables most correlated with Price:
# bedroomCount                     0.405676
# toiletCount                      0.380974
# bathroomCount                    0.357685
# totalParkingCount                0.232839
# epcScore_encoded                 0.230839
# province_encoded                 0.221081
# type_encoded                     0.187026
# hasPhotovoltaicPanels_encoded    0.185391
# hasOffice_encoded                0.177470
# subtype_encoded                  0.170885
# Name: price, dtype: float64

# %%
df.columns.to_list()
# Out:
# ['bedroomCount',
#  'bathroomCount',
#  'habitableSurface',
#  'toiletCount',
#  'postCode',
#  'totalParkingCount',
#  'province_encoded',
#  'type_encoded',
#  'subtype_encoded',
#  'locality_encoded',
#  'epcScore_encoded',
#  'hasAttic_encoded',
#  'hasGarden_encoded',
#  'hasAirConditioning_encoded',
#  'hasArmoredDoor_encoded',
#  'hasVisiophone_encoded',
#  'hasTerrace_encoded',
#  'hasOffice_encoded',
#  'hasSwimmingPool_encoded',
#  'hasFireplace_encoded',
#  'hasBasement_encoded',
#  'hasDressingRoom_encoded',
#  'hasDiningRoom_encoded',
#  'hasLift_encoded',
#  'hasHeatPump_encoded',
#  'hasPhotovoltaicPanels_encoded',
#  'hasLivingRoom_encoded',
#  'price']

# %%
upper = 2000000
lower = 100000
df = df[(df['price'] <= upper) & (df['price'] >= lower)]
# df = df[df['price'] >= lower]
#df.to_csv('cleaned_file', index=False)

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np

df_prepro = df.copy()
columns = ['habitableSurface',  'price']
for col in columns:
    df_prepro[col] = MinMaxScaler().fit_transform(np.array(df_prepro[col]).reshape(-1, 1))
display(df_prepro)

df_prepro.to_csv('cleaned_file.csv', index=False)
# Out:
#        Unnamed: 0  bedroomCount  bathroomCount  habitableSurface  toiletCount  \
# 0               0           2.0            1.0          0.000507          1.0
# 1               1           4.0            2.0          0.001424          3.0
# 2               2           2.0            1.0          0.000437          1.0
# 3               3           2.0            2.0          0.000529          2.0
# 4               4           1.0            1.0          0.000351          1.0
# ...           ...           ...            ...               ...          ...
# 76098       76098           4.0            2.0          0.001273          2.0
# 76099       76099           3.0            1.0          0.000475          1.0
# 76100       76100           3.0            1.0          0.000577          1.0
# 76101       76101           3.0            2.0          0.000567          2.0
# 76102       76102           3.0            2.0          0.000680          2.0
#
# ...

# %%
df_prepro.to_csv('cleaned_file.csv', index=False)

# %%
df = pd.read_csv('cleaned_file.csv')
df.head()
# Out:
#    Unnamed: 0  bedroomCount  bathroomCount  habitableSurface  toiletCount  \
# 0           0           2.0            1.0          0.000507          1.0
# 1           1           4.0            2.0          0.001424          3.0
# 2           2           2.0            1.0          0.000437          1.0
# 3           3           2.0            2.0          0.000529          2.0
# 4           4           1.0            1.0          0.000351          1.0
#
#    postCode  totalParkingCount  province_encoded  type_encoded  \
# 0      1040                1.0                 1             1
# 1      1040                0.0                 1             2
# 2      1040                0.0                 1             1
# 3      1040                0.0                 1             1
# 4      1040                0.0                 1             1
#
#    subtype_encoded  ...  hasSwimmingPool_encoded  hasFireplace_encoded  \
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('cleaned_file.csv')
x  = df.iloc[:, :-1]
y = df.iloc[:, -1]

# Split data into training and testing sets (80% train, 20% test)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.5, random_state=42, shuffle =True)

# Initialize and train the model
model = LinearRegression()
model.fit(x_train, y_train)

# Make predictions on test data
y_pred = model.predict(x_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse:.2f}")
print(f"R^2 Score: {r2:.2f}")
# Out:
# Mean Squared Error: 0.00
# R^2 Score: 0.36

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
import time

# importing the file 

df_RF= pd.read_csv('cleaned_file.csv')
X  = df_RF.iloc[:, :-1]
y = df_RF.iloc[:, -1]

feature_names = df_RF.columns

# set number of iteration 
iterations = 10
best_MSE = float('inf')
best_model = None
best_r2 = None
best_params = None
start_time = time.time()

feature_names = X.columns

for i in range(1, iterations +1 ):
    iteration_start = time.time()

    random_start = np.random.randint(0 , 10000)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state = random_start, shuffle = True)

    n_stimators = np.random.randint(50,1000)
    max_depth = np.random.choice([None, 5, 10, 20, 30])

    # preparing data for training and testing

    model_RF = RandomForestRegressor(n_estimators=n_stimators, max_depth=max_depth, random_state=random_start)
    model_RF.fit(X_train, y_train)
        
    # Predicting the model

    Y_pred_RF = model_RF.predict(X_test)

    MSE = mean_squared_error(y_test, Y_pred_RF)
    r2 = r2_score(y_test, Y_pred_RF)

    if MSE < best_MSE:
        best_MSE = MSE
        best_r2 = r2
        best_model = model_RF
        best_params = {'n_estimators' : n_stimators, 'max_depth' : max_depth, 'random_stat' : random_start}


    iteration_time = time.time() - iteration_start
    print(f"Iteration {i}/{iterations} completed in {iteration_time:.2f} seconds - MSE: {mse:.4f}, R2: {r2:.4f}")

total_time = time.time() - start_time


# Feature importances from best RandomForest
importances = best_model.feature_importances_
importance_df = pd.DataFrame({
    'Feature': feature_names,
    'Importance': importances
}).sort_values(by='Importance', ascending=False)

print("\n==== Summary ====")

print(f"Best MSE: {best_MSE:.4f}")
print(f"Best R2 Score: {best_r2:.4f}")
print(f"Best parameters: {best_params}")
print(f"Total time taken: {total_time:.2f} seconds")

print("\n==== Feature Importances (RandomForest, descending order) ====")
print(importance_df.to_string(index=False))
# Out:
# Iteration 1/10 completed in 844.17 seconds - MSE: 0.0044, R2: 0.7284
# Iteration 2/10 completed in 145.54 seconds - MSE: 0.0044, R2: 0.6820
# Iteration 3/10 completed in 103.86 seconds - MSE: 0.0044, R2: 0.5631
# Iteration 4/10 completed in 472.38 seconds - MSE: 0.0044, R2: 0.7354
# Iteration 5/10 completed in 576.69 seconds - MSE: 0.0044, R2: 0.7298
# Iteration 6/10 completed in 134.61 seconds - MSE: 0.0044, R2: 0.6982
# Iteration 7/10 completed in 556.64 seconds - MSE: 0.0044, R2: 0.7275
# Iteration 8/10 completed in 151.20 seconds - MSE: 0.0044, R2: 0.7367
# Iteration 9/10 completed in 43.14 seconds - MSE: 0.0044, R2: 0.5548
# Iteration 10/10 completed in 304.45 seconds - MSE: 0.0044, R2: 0.7382
#
# ==== Summary ====
# Best MSE: 0.0017
# Best R2 Score: 0.7354
# Best parameters: {'n_estimators': 718, 'max_depth': None, 'random_stat': 4834}
# Total time taken: 3332.96 seconds
#
# ==== Feature Importances (RandomForest, descending order) ====
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
import time
from sklearn.preprocessing import MinMaxScaler
import numpy as np

df= pd.read_csv('cleaned_file.csv')

df_prepro = df.copy()
columns = ['habitableSurface',  'price']
for col in columns:
    df_prepro[col] = StandardScaler().fit_transform(np.array(df_prepro[col]).reshape(-1, 1))

df_RF= df_prepro

X  = df_RF.iloc[:, :-1]
y = df_RF.iloc[:, -1]




feature_names = df_RF.columns


# set number of iteration 
iterations = 10
best_MSE = float('inf')
best_model = None
best_r2 = None
best_params = None
start_time = time.time()

feature_names = X.columns

for i in range(1, iterations +1 ):
    iteration_start = time.time()

    random_start = np.random.randint(0 , 10000)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state = random_start, shuffle = True)

    n_stimators = np.random.randint(50,1000)
    max_depth = np.random.choice([None, 5, 10, 20, 30])

    # preparing data for training and testing

    model_RF = RandomForestRegressor(n_estimators=n_stimators, max_depth=max_depth, random_state=random_start)
    model_RF.fit(X_train, y_train)
        
    # Predicting the model

    Y_pred_RF = model_RF.predict(X_test)

    MSE = mean_squared_error(y_test, Y_pred_RF)
    r2 = r2_score(y_test, Y_pred_RF)

    if MSE < best_MSE:
        best_MSE = MSE
        best_r2 = r2
        best_model = model_RF
        best_params = {'n_estimators' : n_stimators, 'max_depth' : max_depth, 'random_stat' : random_start}


    iteration_time = time.time() - iteration_start
    print(f"Iteration {i}/{iterations} completed in {iteration_time:.2f} seconds - MSE: {mse:.4f}, R2: {r2:.4f}")

total_time = time.time() - start_time


# Feature importances from best RandomForest
importances = best_model.feature_importances_
importance_df = pd.DataFrame({
    'Feature': feature_names,
    'Importance': importances
}).sort_values(by='Importance', ascending=False)

print("\n==== Summary ====")

print(f"Best MSE: {best_MSE:.4f}")
print(f"Best R2 Score: {best_r2:.4f}")
print(f"Best parameters: {best_params}")
print(f"Total time taken: {total_time:.2f} seconds")

print("\n==== Feature Importances (RandomForest, descending order) ====")
print(importance_df.to_string(index=False))
# Out:
# Iteration 1/10 completed in 102.46 seconds - MSE: 0.0044, R2: 0.7113
# Iteration 2/10 completed in 63.60 seconds - MSE: 0.0044, R2: 0.5391
# Iteration 3/10 completed in 190.93 seconds - MSE: 0.0044, R2: 0.7437
# Iteration 4/10 completed in 108.16 seconds - MSE: 0.0044, R2: 0.7483
# Iteration 5/10 completed in 22.80 seconds - MSE: 0.0044, R2: 0.5579
# Iteration 6/10 completed in 216.26 seconds - MSE: 0.0044, R2: 0.7470
# Iteration 7/10 completed in 245.86 seconds - MSE: 0.0044, R2: 0.7408
# Iteration 8/10 completed in 120.15 seconds - MSE: 0.0044, R2: 0.6721
# Iteration 9/10 completed in 8.86 seconds - MSE: 0.0044, R2: 0.5658
# Iteration 10/10 completed in 141.75 seconds - MSE: 0.0044, R2: 0.6900
#
# ==== Summary ====
# Best MSE: 0.2545
# Best R2 Score: 0.7483
# Best parameters: {'n_estimators': 171, 'max_depth': None, 'random_stat': 2969}
# Total time taken: 1220.86 seconds
#
# ==== Feature Importances (RandomForest, descending order) ====
#                       Feature  Importance
# ...

# %%
from sklearn.ensemble import GradientBoostingRegressor

df= pd.read_csv('dataset_wout_price_outliers.csv')

df_prepro = df.copy()
columns = ['habitableSurface',  'price']
for col in columns:
    df_prepro[col] = StandardScaler().fit_transform(np.array(df_prepro[col]).reshape(-1, 1))

df_GB= df_prepro

X  = df_GB.iloc[:, :-1]
y = df_GB.iloc[:, -1]

feature_names_gb = X.columns

# set number of iteration 
iterations = 10
best_MSE = float('inf')
best_model = None
best_r2 = None
best_params = None
start_time = time.time()

feature_names = X.columns

for i in range(1, iterations + 1):
    iteration_start = time.time()

    random_start = np.random.randint(0 , 10000)
    learning_rate = np.random.uniform(0.05, 0.1)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state = random_start)

    n_estimators = np.random.randint(50, 1000)
    max_depth = np.random.choice([None, 5, 10, 20, 30])

    # preparing data for training and testing

    model_GB = GradientBoostingRegressor(n_estimators=n_estimators, learning_rate=learning_rate, max_depth=max_depth, random_state=random_start)
    model_GB.fit(X_train, y_train)
        
    # Predicting the model

    Y_pred_GB = model_GB.predict(X_test)

    MSE = mean_squared_error(y_test, Y_pred_GB)
    r2 = r2_score(y_test, Y_pred_GB)

    if MSE < best_MSE:
        best_MSE = MSE
        best_r2 = r2
        best_model = model_GB
        best_params = {'n_estimators' : n_stimators, 'max_depth' : max_depth, 'random_stat' : random_start}


    iteration_time = time.time() - iteration_start
    print(f"Iteration {i}/{iterations} completed in {iteration_time:.2f} seconds - MSE: {mse:.4f}, R2: {r2:.4f}")

total_time = time.time() - start_time


# Feature importances from best RandomForest
importances_gb = best_model.feature_importances_
importance_gb = pd.DataFrame({
    'Feature': feature_names_gb,
    'Importance': importances_gb
}).sort_values(by='Importance', ascending=False)

print("\n==== Summary ====")

print(f"Best MSE: {best_MSE:.4f}")
print(f"Best R2 Score: {best_r2:.4f}")
print(f"Best parameters: {best_params}")
print(f"Total time taken: {total_time:.2f} seconds")

print("\n==== Feature Importances (RandomForest, descending order) ====")
print(importance_gb.to_string(index=False))
# Out:
# Iteration 1/10 completed in 31.11 seconds - MSE: 0.0044, R2: 0.6971
# Iteration 2/10 completed in 139.14 seconds - MSE: 0.0044, R2: 0.7271
# Iteration 3/10 completed in 167.69 seconds - MSE: 0.0044, R2: 0.7248
# Iteration 4/10 completed in 34.18 seconds - MSE: 0.0044, R2: 0.6957
# Iteration 5/10 completed in 426.56 seconds - MSE: 0.0044, R2: 0.5822
# Iteration 6/10 completed in 416.53 seconds - MSE: 0.0044, R2: 0.4324
# Iteration 7/10 completed in 330.13 seconds - MSE: 0.0044, R2: 0.5876
# Iteration 8/10 completed in 378.03 seconds - MSE: 0.0044, R2: 0.5656
# Iteration 9/10 completed in 891.72 seconds - MSE: 0.0044, R2: 0.4231
# Iteration 10/10 completed in 819.91 seconds - MSE: 0.0044, R2: 0.4276
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 64
#      62 # Feature importances from best RandomForest
# ...

# %%
from catboost import CatBoostRegressor


df= pd.read_csv('dataset_wout_price_outliers.csv')

df_prepro = df.copy()
columns = ['habitableSurface',  'price']
for col in columns:
    df_prepro[col] = StandardScaler().fit_transform(np.array(df_prepro[col]).reshape(-1, 1))

df_CT= df_prepro

X  = df_CT.iloc[:, :-1]
y = df_CT.iloc[:, -1]

feature_names_ct = X.columns

# set number of iteration 
iterations = 10
best_MSE = float('inf')
best_model = None
best_r2 = None
best_params = None
start_time = time.time()

feature_names = X.columns

for i in range(1, iterations + 1):
    iteration_start = time.time()

    random_start = np.random.randint(0 , 10000)
    learning_rate = np.random.uniform(0.05, 0.1)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state = random_start)

    n_estimators = np.random.randint(50, 1000)
    max_depth = np.random.choice([None, 5, 10, 20, 30])

    # preparing data for training and testing

    model_CT = GradientBoostingRegressor(n_estimators=n_estimators, learning_rate=learning_rate, max_depth=max_depth, random_state=random_start)
    model_CT.fit(X_train, y_train)
        
    # Predicting the model

    Y_pred_CT = model_CT.predict(X_test)

    MSE = mean_squared_error(y_test, Y_pred_CT)
    r2 = r2_score(y_test, Y_pred_CT)

    if MSE < best_MSE:
        best_MSE = MSE
        best_r2 = r2
        best_model = model_CT
        best_params = {'n_estimators' : n_stimators, 'max_depth' : max_depth, 'random_stat' : random_start}


    iteration_time = time.time() - iteration_start
    print(f"Iteration {i}/{iterations} completed in {iteration_time:.2f} seconds - MSE: {mse:.4f}, R2: {r2:.4f}")

total_time = time.time() - start_time


# Feature importances from best RandomForest
importances_ct = best_model.feature_importances_
importance_ct = pd.DataFrame({
    'Feature': feature_names_ct,
    'Importance': importances_ct
}).sort_values(by='Importance', ascending=False)

print("\n==== Summary ====")

print(f"Best MSE: {best_MSE:.4f}")
print(f"Best R2 Score: {best_r2:.4f}")
print(f"Best parameters: {best_params}")
print(f"Total time taken: {total_time:.2f} seconds")

print("\n==== Feature Importances (RandomForest, descending order) ====")
print(importance_ct.to_string(index=False))
# Out:
# Iteration 1/10 completed in 33.05 seconds - MSE: 0.0044, R2: 0.6987
# Iteration 2/10 completed in 210.80 seconds - MSE: 0.0044, R2: 0.5708
# Iteration 3/10 completed in 984.49 seconds - MSE: 0.0044, R2: 0.4219
# Iteration 4/10 completed in 59.63 seconds - MSE: 0.0044, R2: 0.7151
# Iteration 5/10 completed in 700.60 seconds - MSE: 0.0044, R2: 0.4295
# Iteration 6/10 completed in 20.36 seconds - MSE: 0.0044, R2: 0.6746
# Iteration 7/10 completed in 32.13 seconds - MSE: 0.0044, R2: 0.4468
# Iteration 8/10 completed in 378.78 seconds - MSE: 0.0044, R2: 0.4369
# Iteration 9/10 completed in 263.14 seconds - MSE: 0.0044, R2: 0.5678
# Iteration 10/10 completed in 74.83 seconds - MSE: 0.0044, R2: 0.7197
#
# ==== Summary ====
# Best MSE: 0.2807
# Best R2 Score: 0.7197
# Best parameters: {'n_estimators': 538, 'max_depth': 5, 'random_stat': 2675}
# Total time taken: 2757.85 seconds
#
# ==== Feature Importances (RandomForest, descending order) ====
#                       Feature  Importance
# ...

# %%
df['pricePerSurface'] = df['price'] / df['habitableSurface']
df.columns.str.strip()
price_col_index = df.columns.get_loc('price')
cols = list(df.columns)
cols.insert(price_col_index, cols.pop(cols.index('pricePerSurface'))) 
df = df[cols]
df.drop('habitableSurface', inplace=True, axis=1)
df.drop('price', inplace=True, axis=1)
df.to_csv('updated_pricePereSurface_file.csv')
df.columns.to_flat_index()
print(len(df.columns))

df.to_csv('updated_pricePereSurface_file.csv')
